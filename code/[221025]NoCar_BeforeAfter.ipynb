# %% [markdown]
# ## 0.환경설정

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# 시각화 관련
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
from collections import Counter
from PIL import Image
from matplotlib import rc

# 그래프에서 한글 폰트 깨지는 문제에 대한 대처(전역 글꼴 설정)
import matplotlib.font_manager as fm
import warnings
warnings.filterwarnings(action='ignore') 

import matplotlib
matplotlib.rcParams['font.family'] ='Malgun Gothic'
matplotlib.rcParams['axes.unicode_minus'] =False

# %% [markdown]
# ## 1. 환경

# %%
d1 = pd.read_csv('data/B039. 서울시 대기환경정보/2. 파일데이터/TV_OP_1HRTMS.txt',delimiter = '|')
d1.columns=['측정날짜','측정소_행정코드','대기환경등급','통합대기환경지수','지수결정물질',
             '이산화질소_농도','이산화질소_지수','오존_농도','오존_지수',
             '일산화탄소_농도','일산화탄소_지수','아황산가스_농도','아황산가스_지수',
             '미세먼지_농도','미세먼지_지수','미세먼지(24시)농도','미세먼지(24시)지수결정물질',
             '권역코드','권역명','측정소명']
d1.replace('(.*)`(.*)',r'\1\2',regex = True,inplace=True)
d1.head()
# Out:
#             측정날짜 측정소_행정코드 대기환경등급 통합대기환경지수 지수결정물질 이산화질소_농도 이산화질소_지수   오존_농도  \
# 0  `201111142300  `111123   `점검중     `-99   `점검중     `점검중        `    `점검중
# 1  `202008220800  `111123    `좋음      `29  `PM25   `0.013      `22  `0.012
# 2  `201108020100  `111123   `점검중     `-99   `점검중   `0.014      `23  `0.006
# 3  `202005031100  `111123    `보통      `56  `PM25   `0.011      `18  `0.025
# 4  `201210131900  `111123   `점검중     `-99   `점검중   `0.065     `103  `0.006
#
#   오존_지수 일산화탄소_농도 일산화탄소_지수 아황산가스_농도 아황산가스_지수 미세먼지_농도 미세먼지_지수 미세먼지(24시)농도  \
# 0     `     `점검중        `     `점검중        `    `점검중      `0        `점검중
# 1   `20     `0.3       `8   `0.002       `5     `14     `27         `16
# 2    `8     `0.2       `5   `0.005      `13     `14     `39         `16
# 3   `42     `0.4      `10   `0.003       `8     `36     `53         `33
# 4    `8     `0.5      `13   `0.014      `35     `44     `84         `45
#
#   미세먼지(24시)지수결정물질  권역코드   권역명  측정소명
# 0               `  `100  `도심권  `종로구
# ...

# %% [markdown]
# ## 참고.
# * 문자열 치환: https://ponyozzang.tistory.com/614
